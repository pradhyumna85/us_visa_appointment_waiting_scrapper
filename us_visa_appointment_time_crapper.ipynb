# %% [markdown]
# # Install dependencies

# %%
# pip install pytz
# Out:
# Requirement already satisfied: pytz in /opt/conda/lib/python3.10/site-packages (2022.5)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # imports

# %%
import pandas as pd
from datetime import datetime
import pytz
import requests
import json
from concurrent.futures import ThreadPoolExecutor
import os
import ast

# %% [markdown]
# # Scrape place codes

# %%
js_file_url = "https://travel.state.gov/etc/designs/travel/TSGglobal_libs/data/PostsVWT.js"

# %%
content = requests.get(js_file_url).text

# %%
print(content)
# Out:
# (function($){
#     window.travelStateGov = window.travelStateGov || {};
#     travelStateGov.PostsVWT = {
#         sourceData : [
#             {"code":"P142","value":"N Djamena"},
#             {"code":"P142","value":"N'Djamena"},
#
#          {"code":"abidjan","value":"Abidjan"}
#         ,
#          {"code":"P2","value":"Abu Dhabi"}
#         ,
#          {"code":"P3","value":"Abuja"}
#         ,
#          {"code":"P4","value":"Accra"}
#         ,
#          {"code":"adana","value":"Adana"}
#         ,
#          {"code":"P5","value":"Addis Ababa"}
#         ,
#          {"code":"P6","value":"Algiers"}
#         ,
#          {"code":"P7","value":"Almaty"}
#         ,
#          {"code":"P8","value":"Amman"}
#         ,
#          {"code":"P9","value":"Amsterdam"}
#         ,
#          {"code":"P10","value":"Ankara"}
#         ,
#          {"code":"P11","value":"Antananarivo"}
#         ,
#          {"code":"P225","value":"Apia"}
#         ,
#          {"code":"P12","value":"Ashgabat"}
#         ,
#          {"code":"P13","value":"Asmara"}
#         ,
#          {"code":"astana","value":"Astana"}
#         ,
#          {"code":"P15","value":"Asuncion"}
#         ,
#          {"code":"athens","value":"Athens"}
#         ,
#          {"code":"P17","value":"Auckland"}
#         ,
#          {"code":"P226","value":"Baghdad"}
#         ,
#          {"code":"P19","value":"Baku"}
#         ,
#          {"code":"P20","value":"Bamako"}
#         ,
#          {"code":"P21","value":"Bandar Seri Begawan"}
#         ,
#          {"code":"P22","value":"Bangkok"}
#         ,
#          {"code":"bangui","value":"Bangui"}
#         ,
#          {"code":"banjul","value":"Banjul"}
#         ,
#          {"code":"barcelona","value":"Barcelona"}
#         ,
#          {"code":"P24","value":"Beijing"}
#         ,
#          {"code":"P25","value":"Beirut"}
#         ,
#          {"code":"P26","value":"Belfast"}
#         ,
#          {"code":"P27","value":"Belgrade"}
#         ,
#          {"code":"P28","value":"Belmopan"}
#         ,
#          {"code":"P29","value":"Berlin"}
#         ,
#          {"code":"P30","value":"Bern"}
#         ,
#          {"code":"P31","value":"Bishkek"}
#         ,
#          {"code":"P32","value":"Bogota"}
#         ,
#          {"code":"P33","value":"Brasilia"}
#         ,
#          {"code":"P34","value":"Bratislava"}
#         ,
#          {"code":"P35","value":"Brazzaville"}
#         ,
#          {"code":"P36","value":"Bridgetown"}
#         ,
#          {"code":"P37","value":"Brussels"}
#         ,
#          {"code":"P38","value":"Bucharest"}
#         ,
#          {"code":"P39","value":"Budapest"}
#         ,
#          {"code":"P40","value":"Buenos Aires"}
#         ,
#          {"code":"P41","value":"Bujumbura"}
#         ,
#          {"code":"P42","value":"Cairo"}
#         ,
#          {"code":"P43","value":"Calgary"}
#         ,
#          {"code":"canberra","value":"Canberra"}
#         ,
#          {"code":"P44","value":"Cape Town"}
#         ,
#          {"code":"P45","value":"Caracas"}
#         ,
#          {"code":"P46","value":"Casablanca"}
#         ,
#          {"code":"P47","value":"Chengdu"}
#         ,
#          {"code":"P48","value":"Chennai ( Madras)"}
#         ,
#          {"code":"P49","value":"Chiang Mai"}
#         ,
#          {"code":"P50","value":"Chisinau"}
#         ,
#          {"code":"P51","value":"Ciudad Juarez"}
#         ,
#          {"code":"P52","value":"Colombo"}
#         ,
#          {"code":"P53","value":"Conakry"}
#         ,
#          {"code":"P54","value":"Copenhagen"}
#         ,
#          {"code":"P55","value":"Cotonou"}
#         ,
#          {"code":"P223","value":"Curacao"}
#         ,
#          {"code":"P56","value":"Dakar"}
#         ,
#          {"code":"P57","value":"Damascus"}
#         ,
#          {"code":"P58","value":"Dar Es Salaam"}
#         ,
#          {"code":"P59","value":"Dhahran"}
#         ,
#          {"code":"P60","value":"Dhaka"}
#         ,
#          {"code":"P227","value":"Dili"}
#         ,
#          {"code":"P61","value":"Djibouti"}
#         ,
#          {"code":"P62","value":"Doha"}
#         ,
#          {"code":"P63","value":"Dubai"}
#         ,
#          {"code":"P64","value":"Dublin"}
#         ,
#          {"code":"P65","value":"Durban"}
#         ,
#          {"code":"P66","value":"Dushanbe"}
#         ,
#          {"code":"erbil","value":"Erbil"}
#         ,
#          {"code":"P67","value":"Florence"}
#         ,
#          {"code":"P68","value":"Frankfurt"}
#         ,
#          {"code":"P69","value":"Freetown"}
#         ,
#          {"code":"fukuoka","value":"Fukuoka"}
#         ,
#          {"code":"P70","value":"Gaborone"}
#         ,
#          {"code":"P71","value":"Georgetown"}
#         ,
#          {"code":"P72","value":"Guadalajara"}
#         ,
#          {"code":"P73","value":"Guangzhou"}
#         ,
#          {"code":"P74","value":"Guatemala City"}
#         ,
#          {"code":"P75","value":"Guayaquil"}
#         ,
#          {"code":"P76","value":"Halifax"}
#         ,
#          {"code":"P77","value":"Hamilton"}
#         ,
#          {"code":"P78","value":"Hanoi"}
#         ,
#          {"code":"P79","value":"Harare"}
#         ,
#          {"code":"P80","value":"Havana"}
#         ,
#          {"code":"P81","value":"Helsinki"}
#         ,
#          {"code":"P82","value":"Hermosillo"}
#         ,
#          {"code":"P83","value":"Ho Chi Minh City"}
#         ,
#          {"code":"P84","value":"Hong Kong"}
#         ,
#          {"code":"P85","value":"Hyderabad"}
#         ,
#          {"code":"P86","value":"Islamabad"}
#         ,
#          {"code":"P87","value":"Istanbul"}
#         ,
#          {"code":"P88","value":"Jakarta"}
#         ,
#          {"code":"P89","value":"Jeddah"}
#         ,
#          {"code":"P90","value":"Jerusalem"}
#         ,
#          {"code":"P91","value":"Johannesburg"}
#         ,
#          {"code":"P228","value":"Juba"}
#         ,
#          {"code":"P229","value":"Kabul"}
#         ,
#          {"code":"P93","value":"Kampala"}
#         ,
#          {"code":"kaohsiung","value":"Kaohsiung"}
#         ,
#          {"code":"P94","value":"Karachi"}
#         ,
#          {"code":"P95","value":"Kathmandu"}
#         ,
#          {"code":"P96","value":"Khartoum"}
#         ,
#          {"code":"P97","value":"Kigali"}
#         ,
#          {"code":"P98","value":"Kingston"}
#         ,
#          {"code":"P99","value":"Kinshasa"}
#         ,
#          {"code":"P100","value":"Kolkata"}
#         ,
#          {"code":"P101","value":"Kolonia"}
#         ,
#          {"code":"P102","value":"Koror"}
#         ,
#          {"code":"P103","value":"Krakow"}
#         ,
#          {"code":"P104","value":"Kuala Lumpur"}
#         ,
#          {"code":"P105","value":"Kuwait"}
#         ,
#          {"code":"P106","value":"Kyiv"}
#         ,
#          {"code":"P107","value":"La Paz"}
#         ,
#          {"code":"P108","value":"Lagos"}
#         ,
#          {"code":"lahore","value":"Lahore"}
#         ,
#          {"code":"P109","value":"Libreville"}
#         ,
#          {"code":"P110","value":"Lilongwe"}
#         ,
#          {"code":"P111","value":"Lima"}
#         ,
#          {"code":"P112","value":"Lisbon"}
#         ,
#          {"code":"P113","value":"Ljubljana"}
#         ,
#          {"code":"lome","value":"Lome"}
#         ,
#          {"code":"P115","value":"London"}
#         ,
#          {"code":"P116","value":"Luanda"}
#         ,
#          {"code":"P117","value":"Lusaka"}
#         ,
#          {"code":"P118","value":"Luxembourg"}
#         ,
#          {"code":"P119","value":"Madrid"}
#         ,
#          {"code":"P120","value":"Majuro"}
#         ,
#          {"code":"P121","value":"Malabo"}
#         ,
#          {"code":"managua","value":"Managua"}
#         ,
#          {"code":"P123","value":"Manama"}
#         ,
#          {"code":"P124","value":"Manila"}
#         ,
#          {"code":"P125","value":"Maputo"}
#         ,
#          {"code":"marseille","value":"Marseille"}
#         ,
#          {"code":"P126","value":"Maseru"}
#         ,
#          {"code":"P127","value":"Matamoros"}
#         ,
#          {"code":"P128","value":"Mbabane"}
#         ,
#          {"code":"P129","value":"Melbourne"}
#         ,
#          {"code":"P130","value":"Merida"}
#         ,
#          {"code":"mexicali_tpf","value":"Mexicali Tpf"}
#         ,
#          {"code":"P131","value":"Mexico City"}
#         ,
#          {"code":"P132","value":"Milan"}
#         ,
#          {"code":"P133","value":"Minsk"}
#         ,
#          {"code":"P134","value":"Monrovia"}
#         ,
#          {"code":"P135","value":"Monterrey"}
#         ,
#          {"code":"P136","value":"Montevideo"}
#         ,
#          {"code":"P137","value":"Montreal"}
#         ,
#          {"code":"P138","value":"Moscow"}
#         ,
#          {"code":"P139","value":"Mumbai (Bombay)"}
#         ,
#          {"code":"P140","value":"Munich"}
#         ,
#          {"code":"P141","value":"Muscat"}
#         ,
#          {"code":"P142","value":"N`Djamena"}
#         ,
#          {"code":"P143","value":"Naha"}
#         ,
#          {"code":"P144","value":"Nairobi"}
#         ,
#          {"code":"P145","value":"Naples"}
#         ,
#          {"code":"P146","value":"Nassau"}
#         ,
#          {"code":"P147","value":"New Delhi"}
#         ,
#          {"code":"P148","value":"Niamey"}
#         ,
#          {"code":"P149","value":"Nicosia"}
#         ,
#          {"code":"P150","value":"Nogales"}
#         ,
#          {"code":"P151","value":"Nouakchott"}
#         ,
#          {"code":"P152","value":"Nuevo Laredo"}
#         ,
#          {"code":"P153","value":"Osaka-Kobe"}
#         ,
#          {"code":"P154","value":"Oslo"}
#         ,
#          {"code":"P155","value":"Ottawa"}
#         ,
#          {"code":"P156","value":"Ouagadougou"}
#         ,
#          {"code":"P157","value":"Panama City"}
#         ,
#          {"code":"P158","value":"Paramaribo"}
#         ,
#          {"code":"P159","value":"Paris"}
#         ,
#          {"code":"P160","value":"Perth"}
#         ,
#          {"code":"P161","value":"Phnom Penh"}
#         ,
#          {"code":"P162","value":"Podgorica"}
#         ,
#          {"code":"ponta_delgada","value":"Ponta Delgada"}
#         ,
#          {"code":"P164","value":"Port Au Prince"}
#         ,
#          {"code":"P165","value":"Port Louis"}
#         ,
#          {"code":"P166","value":"Port Moresby"}
#         ,
#          {"code":"P167","value":"Port Of Spain"}
#         ,
#          {"code":"porto_alegre","value":"Porto Alegre"}
#         ,
#          {"code":"P168","value":"Prague"}
#         ,
#          {"code":"P169","value":"Praia"}
#         ,
#          {"code":"pretoria","value":"Pretoria"}
#         ,
#          {"code":"P231","value":"Pristina"}
#         ,
#          {"code":"P170","value":"Quebec"}
#         ,
#          {"code":"P171","value":"Quito"}
#         ,
#          {"code":"P172","value":"Rangoon"}
#         ,
#          {"code":"P173","value":"Recife"}
#         ,
#          {"code":"P174","value":"Reykjavik"}
#         ,
#          {"code":"P175","value":"Riga"}
#         ,
#          {"code":"P230","value":"Rio De Janeiro"}
#         ,
#          {"code":"P177","value":"Riyadh"}
#         ,
#          {"code":"P178","value":"Rome"}
#         ,
#          {"code":"P179","value":"San Jose"}
#         ,
#          {"code":"P180","value":"San Salvador"}
#         ,
#          {"code":"P181","value":"Sanaa"}
#         ,
#          {"code":"P182","value":"Santiago"}
#         ,
#          {"code":"P183","value":"Santo Domingo"}
#         ,
#          {"code":"P184","value":"Sao Paulo"}
#         ,
#          {"code":"P224","value":"Sapporo"}
#         ,
#          {"code":"P185","value":"Sarajevo"}
#         ,
#          {"code":"P186","value":"Seoul"}
#         ,
#          {"code":"P187","value":"Shanghai"}
#         ,
#          {"code":"P188","value":"Shenyang"}
#         ,
#          {"code":"P189","value":"Singapore"}
#         ,
#          {"code":"P190","value":"Skopje"}
#         ,
#          {"code":"P191","value":"Sofia"}
#         ,
#          {"code":"st_georges","value":"St Georges"}
#         ,
#          {"code":"P192","value":"St Petersburg"}
#         ,
#          {"code":"P193","value":"Stockholm"}
#         ,
#          {"code":"P194","value":"Surabaya"}
#         ,
#          {"code":"P195","value":"Suva"}
#         ,
#          {"code":"P196","value":"Sydney"}
#         ,
#          {"code":"P197","value":"Taipei"}
#         ,
#          {"code":"P198","value":"Tallinn"}
#         ,
#          {"code":"P199","value":"Tashkent"}
#         ,
#          {"code":"P200","value":"Tbilisi"}
#         ,
#          {"code":"P201","value":"Tegucigalpa"}
#         ,
#          {"code":"P202","value":"Tel Aviv"}
#         ,
#          {"code":"tijuana","value":"Tijuana"}
#         ,
#          {"code":"P203","value":"Tijuana Tpf"}
#         ,
#          {"code":"P204","value":"Tirana"}
#         ,
#          {"code":"P205","value":"Tokyo"}
#         ,
#          {"code":"P206","value":"Toronto"}
#         ,
#          {"code":"P207","value":"Tripoli"}
#         ,
#          {"code":"P208","value":"Tunis"}
#         ,
#          {"code":"P209","value":"Ulaanbaatar"}
#         ,
#          {"code":"usun-new_york","value":"Usun-New York"}
#         ,
#          {"code":"P210","value":"Valletta"}
#         ,
#          {"code":"P211","value":"Vancouver"}
#         ,
#          {"code":"P212","value":"Vienna"}
#         ,
#          {"code":"P213","value":"Vientiane"}
#         ,
#          {"code":"P214","value":"Vilnius"}
#         ,
#          {"code":"P215","value":"Vladivostok"}
#         ,
#          {"code":"P216","value":"Warsaw"}
#         ,
#          {"code":"P217","value":"Windhoek"}
#         ,
#          {"code":"P218","value":"Yaounde"}
#         ,
#          {"code":"yekaterinburg","value":"Yekaterinburg"}
#         ,
#          {"code":"P220","value":"Yerevan"}
#         ,
#          {"code":"P221","value":"Zagreb"}
#
#         ]
#     };
# })(jQuery)

# %%
codes = ast.literal_eval('['+content.split('[')[1].split(']')[0]+']')

# %%
codes
# Out:
# [{'code': 'P142', 'value': 'N Djamena'},
#  {'code': 'P142', 'value': "N'Djamena"},
#  {'code': 'abidjan', 'value': 'Abidjan'},
#  {'code': 'P2', 'value': 'Abu Dhabi'},
#  {'code': 'P3', 'value': 'Abuja'},
#  {'code': 'P4', 'value': 'Accra'},
#  {'code': 'adana', 'value': 'Adana'},
#  {'code': 'P5', 'value': 'Addis Ababa'},
#  {'code': 'P6', 'value': 'Algiers'},
#  {'code': 'P7', 'value': 'Almaty'},
#  {'code': 'P8', 'value': 'Amman'},
#  {'code': 'P9', 'value': 'Amsterdam'},
#  {'code': 'P10', 'value': 'Ankara'},
#  {'code': 'P11', 'value': 'Antananarivo'},
#  {'code': 'P225', 'value': 'Apia'},
#  {'code': 'P12', 'value': 'Ashgabat'},
#  {'code': 'P13', 'value': 'Asmara'},
#  {'code': 'astana', 'value': 'Astana'},
#  {'code': 'P15', 'value': 'Asuncion'},
#  {'code': 'athens', 'value': 'Athens'},
#  {'code': 'P17', 'value': 'Auckland'},
#  {'code': 'P226', 'value': 'Baghdad'},
#  {'code': 'P19', 'value': 'Baku'},
#  {'code': 'P20', 'value': 'Bamako'},
#  {'code': 'P21', 'value': 'Bandar Seri Begawan'},
#  {'code': 'P22', 'value': 'Bangkok'},
#  {'code': 'bangui', 'value': 'Bangui'},
#  {'code': 'banjul', 'value': 'Banjul'},
#  {'code': 'barcelona', 'value': 'Barcelona'},
#  {'code': 'P24', 'value': 'Beijing'},
#  {'code': 'P25', 'value': 'Beirut'},
#  {'code': 'P26', 'value': 'Belfast'},
#  {'code': 'P27', 'value': 'Belgrade'},
#  {'code': 'P28', 'value': 'Belmopan'},
#  {'code': 'P29', 'value': 'Berlin'},
#  {'code': 'P30', 'value': 'Bern'},
#  {'code': 'P31', 'value': 'Bishkek'},
#  {'code': 'P32', 'value': 'Bogota'},
#  {'code': 'P33', 'value': 'Brasilia'},
#  {'code': 'P34', 'value': 'Bratislava'},
#  {'code': 'P35', 'value': 'Brazzaville'},
#  {'code': 'P36', 'value': 'Bridgetown'},
#  {'code': 'P37', 'value': 'Brussels'},
#  {'code': 'P38', 'value': 'Bucharest'},
#  {'code': 'P39', 'value': 'Budapest'},
#  {'code': 'P40', 'value': 'Buenos Aires'},
#  {'code': 'P41', 'value': 'Bujumbura'},
#  {'code': 'P42', 'value': 'Cairo'},
#  {'code': 'P43', 'value': 'Calgary'},
#  {'code': 'canberra', 'value': 'Canberra'},
#  {'code': 'P44', 'value': 'Cape Town'},
#  {'code': 'P45', 'value': 'Caracas'},
#  {'code': 'P46', 'value': 'Casablanca'},
#  {'code': 'P47', 'value': 'Chengdu'},
#  {'code': 'P48', 'value': 'Chennai ( Madras)'},
#  {'code': 'P49', 'value': 'Chiang Mai'},
#  {'code': 'P50', 'value': 'Chisinau'},
#  {'code': 'P51', 'value': 'Ciudad Juarez'},
#  {'code': 'P52', 'value': 'Colombo'},
#  {'code': 'P53', 'value': 'Conakry'},
#  {'code': 'P54', 'value': 'Copenhagen'},
#  {'code': 'P55', 'value': 'Cotonou'},
#  {'code': 'P223', 'value': 'Curacao'},
#  {'code': 'P56', 'value': 'Dakar'},
#  {'code': 'P57', 'value': 'Damascus'},
#  {'code': 'P58', 'value': 'Dar Es Salaam'},
#  {'code': 'P59', 'value': 'Dhahran'},
#  {'code': 'P60', 'value': 'Dhaka'},
#  {'code': 'P227', 'value': 'Dili'},
#  {'code': 'P61', 'value': 'Djibouti'},
#  {'code': 'P62', 'value': 'Doha'},
#  {'code': 'P63', 'value': 'Dubai'},
#  {'code': 'P64', 'value': 'Dublin'},
#  {'code': 'P65', 'value': 'Durban'},
#  {'code': 'P66', 'value': 'Dushanbe'},
#  {'code': 'erbil', 'value': 'Erbil'},
#  {'code': 'P67', 'value': 'Florence'},
#  {'code': 'P68', 'value': 'Frankfurt'},
#  {'code': 'P69', 'value': 'Freetown'},
#  {'code': 'fukuoka', 'value': 'Fukuoka'},
#  {'code': 'P70', 'value': 'Gaborone'},
#  {'code': 'P71', 'value': 'Georgetown'},
#  {'code': 'P72', 'value': 'Guadalajara'},
#  {'code': 'P73', 'value': 'Guangzhou'},
#  {'code': 'P74', 'value': 'Guatemala City'},
#  {'code': 'P75', 'value': 'Guayaquil'},
#  {'code': 'P76', 'value': 'Halifax'},
#  {'code': 'P77', 'value': 'Hamilton'},
#  {'code': 'P78', 'value': 'Hanoi'},
#  {'code': 'P79', 'value': 'Harare'},
#  {'code': 'P80', 'value': 'Havana'},
#  {'code': 'P81', 'value': 'Helsinki'},
#  {'code': 'P82', 'value': 'Hermosillo'},
#  {'code': 'P83', 'value': 'Ho Chi Minh City'},
#  {'code': 'P84', 'value': 'Hong Kong'},
#  {'code': 'P85', 'value': 'Hyderabad'},
#  {'code': 'P86', 'value': 'Islamabad'},
#  {'code': 'P87', 'value': 'Istanbul'},
#  {'code': 'P88', 'value': 'Jakarta'},
#  {'code': 'P89', 'value': 'Jeddah'},
#  {'code': 'P90', 'value': 'Jerusalem'},
#  {'code': 'P91', 'value': 'Johannesburg'},
#  {'code': 'P228', 'value': 'Juba'},
#  {'code': 'P229', 'value': 'Kabul'},
#  {'code': 'P93', 'value': 'Kampala'},
#  {'code': 'kaohsiung', 'value': 'Kaohsiung'},
#  {'code': 'P94', 'value': 'Karachi'},
#  {'code': 'P95', 'value': 'Kathmandu'},
#  {'code': 'P96', 'value': 'Khartoum'},
#  {'code': 'P97', 'value': 'Kigali'},
#  {'code': 'P98', 'value': 'Kingston'},
#  {'code': 'P99', 'value': 'Kinshasa'},
#  {'code': 'P100', 'value': 'Kolkata'},
#  {'code': 'P101', 'value': 'Kolonia'},
#  {'code': 'P102', 'value': 'Koror'},
#  {'code': 'P103', 'value': 'Krakow'},
#  {'code': 'P104', 'value': 'Kuala Lumpur'},
#  {'code': 'P105', 'value': 'Kuwait'},
#  {'code': 'P106', 'value': 'Kyiv'},
#  {'code': 'P107', 'value': 'La Paz'},
#  {'code': 'P108', 'value': 'Lagos'},
#  {'code': 'lahore', 'value': 'Lahore'},
#  {'code': 'P109', 'value': 'Libreville'},
#  {'code': 'P110', 'value': 'Lilongwe'},
#  {'code': 'P111', 'value': 'Lima'},
#  {'code': 'P112', 'value': 'Lisbon'},
#  {'code': 'P113', 'value': 'Ljubljana'},
#  {'code': 'lome', 'value': 'Lome'},
#  {'code': 'P115', 'value': 'London'},
#  {'code': 'P116', 'value': 'Luanda'},
#  {'code': 'P117', 'value': 'Lusaka'},
#  {'code': 'P118', 'value': 'Luxembourg'},
#  {'code': 'P119', 'value': 'Madrid'},
#  {'code': 'P120', 'value': 'Majuro'},
#  {'code': 'P121', 'value': 'Malabo'},
#  {'code': 'managua', 'value': 'Managua'},
#  {'code': 'P123', 'value': 'Manama'},
#  {'code': 'P124', 'value': 'Manila'},
#  {'code': 'P125', 'value': 'Maputo'},
#  {'code': 'marseille', 'value': 'Marseille'},
#  {'code': 'P126', 'value': 'Maseru'},
#  {'code': 'P127', 'value': 'Matamoros'},
#  {'code': 'P128', 'value': 'Mbabane'},
#  {'code': 'P129', 'value': 'Melbourne'},
#  {'code': 'P130', 'value': 'Merida'},
#  {'code': 'mexicali_tpf', 'value': 'Mexicali Tpf'},
#  {'code': 'P131', 'value': 'Mexico City'},
#  {'code': 'P132', 'value': 'Milan'},
#  {'code': 'P133', 'value': 'Minsk'},
#  {'code': 'P134', 'value': 'Monrovia'},
#  {'code': 'P135', 'value': 'Monterrey'},
#  {'code': 'P136', 'value': 'Montevideo'},
#  {'code': 'P137', 'value': 'Montreal'},
#  {'code': 'P138', 'value': 'Moscow'},
#  {'code': 'P139', 'value': 'Mumbai (Bombay)'},
#  {'code': 'P140', 'value': 'Munich'},
#  {'code': 'P141', 'value': 'Muscat'},
#  {'code': 'P142', 'value': 'N`Djamena'},
#  {'code': 'P143', 'value': 'Naha'},
#  {'code': 'P144', 'value': 'Nairobi'},
#  {'code': 'P145', 'value': 'Naples'},
#  {'code': 'P146', 'value': 'Nassau'},
#  {'code': 'P147', 'value': 'New Delhi'},
#  {'code': 'P148', 'value': 'Niamey'},
#  {'code': 'P149', 'value': 'Nicosia'},
#  {'code': 'P150', 'value': 'Nogales'},
#  {'code': 'P151', 'value': 'Nouakchott'},
#  {'code': 'P152', 'value': 'Nuevo Laredo'},
#  {'code': 'P153', 'value': 'Osaka-Kobe'},
#  {'code': 'P154', 'value': 'Oslo'},
#  {'code': 'P155', 'value': 'Ottawa'},
#  {'code': 'P156', 'value': 'Ouagadougou'},
#  {'code': 'P157', 'value': 'Panama City'},
#  {'code': 'P158', 'value': 'Paramaribo'},
#  {'code': 'P159', 'value': 'Paris'},
#  {'code': 'P160', 'value': 'Perth'},
#  {'code': 'P161', 'value': 'Phnom Penh'},
#  {'code': 'P162', 'value': 'Podgorica'},
#  {'code': 'ponta_delgada', 'value': 'Ponta Delgada'},
#  {'code': 'P164', 'value': 'Port Au Prince'},
#  {'code': 'P165', 'value': 'Port Louis'},
#  {'code': 'P166', 'value': 'Port Moresby'},
#  {'code': 'P167', 'value': 'Port Of Spain'},
#  {'code': 'porto_alegre', 'value': 'Porto Alegre'},
#  {'code': 'P168', 'value': 'Prague'},
#  {'code': 'P169', 'value': 'Praia'},
#  {'code': 'pretoria', 'value': 'Pretoria'},
#  {'code': 'P231', 'value': 'Pristina'},
#  {'code': 'P170', 'value': 'Quebec'},
#  {'code': 'P171', 'value': 'Quito'},
#  {'code': 'P172', 'value': 'Rangoon'},
#  {'code': 'P173', 'value': 'Recife'},
#  {'code': 'P174', 'value': 'Reykjavik'},
#  {'code': 'P175', 'value': 'Riga'},
#  {'code': 'P230', 'value': 'Rio De Janeiro'},
#  {'code': 'P177', 'value': 'Riyadh'},
#  {'code': 'P178', 'value': 'Rome'},
#  {'code': 'P179', 'value': 'San Jose'},
#  {'code': 'P180', 'value': 'San Salvador'},
#  {'code': 'P181', 'value': 'Sanaa'},
#  {'code': 'P182', 'value': 'Santiago'},
#  {'code': 'P183', 'value': 'Santo Domingo'},
#  {'code': 'P184', 'value': 'Sao Paulo'},
#  {'code': 'P224', 'value': 'Sapporo'},
#  {'code': 'P185', 'value': 'Sarajevo'},
#  {'code': 'P186', 'value': 'Seoul'},
#  {'code': 'P187', 'value': 'Shanghai'},
#  {'code': 'P188', 'value': 'Shenyang'},
#  {'code': 'P189', 'value': 'Singapore'},
#  {'code': 'P190', 'value': 'Skopje'},
#  {'code': 'P191', 'value': 'Sofia'},
#  {'code': 'st_georges', 'value': 'St Georges'},
#  {'code': 'P192', 'value': 'St Petersburg'},
#  {'code': 'P193', 'value': 'Stockholm'},
#  {'code': 'P194', 'value': 'Surabaya'},
#  {'code': 'P195', 'value': 'Suva'},
#  {'code': 'P196', 'value': 'Sydney'},
#  {'code': 'P197', 'value': 'Taipei'},
#  {'code': 'P198', 'value': 'Tallinn'},
#  {'code': 'P199', 'value': 'Tashkent'},
#  {'code': 'P200', 'value': 'Tbilisi'},
#  {'code': 'P201', 'value': 'Tegucigalpa'},
#  {'code': 'P202', 'value': 'Tel Aviv'},
#  {'code': 'tijuana', 'value': 'Tijuana'},
#  {'code': 'P203', 'value': 'Tijuana Tpf'},
#  {'code': 'P204', 'value': 'Tirana'},
#  {'code': 'P205', 'value': 'Tokyo'},
#  {'code': 'P206', 'value': 'Toronto'},
#  {'code': 'P207', 'value': 'Tripoli'},
#  {'code': 'P208', 'value': 'Tunis'},
#  {'code': 'P209', 'value': 'Ulaanbaatar'},
#  {'code': 'usun-new_york', 'value': 'Usun-New York'},
#  {'code': 'P210', 'value': 'Valletta'},
#  {'code': 'P211', 'value': 'Vancouver'},
#  {'code': 'P212', 'value': 'Vienna'},
#  {'code': 'P213', 'value': 'Vientiane'},
#  {'code': 'P214', 'value': 'Vilnius'},
#  {'code': 'P215', 'value': 'Vladivostok'},
#  {'code': 'P216', 'value': 'Warsaw'},
#  {'code': 'P217', 'value': 'Windhoek'},
#  {'code': 'P218', 'value': 'Yaounde'},
#  {'code': 'yekaterinburg', 'value': 'Yekaterinburg'},
#  {'code': 'P220', 'value': 'Yerevan'},
#  {'code': 'P221', 'value': 'Zagreb'}]

# %%
type(codes)
# Out:
# list

# %%
type(codes[0])
# Out:
# dict

# %%
## or read from a pre saved json file
# with open('place_codes.json','r') as fp:
#     codes = json.load(fp=fp)['sourceData']
# codes

# %% [markdown]
# # Function to request visa waiting time with place id as input

# %%
def get_wait_times(cid : str,name: str = 'NA') -> dict:
    query_str = f"https://travel.state.gov/content/travel/resources/database/database.getVisaWaitTimes.html?cid={cid}&aid=VisaWaitTimesHomePage"
    response = requests.get(query_str)
    output = response.text.strip().split('|')
    output_days = [item for item in output]
    labels = ["Interview Required Visitors (B1/B2)","Interview Required Students/Exchange Visitors (F, M, J)",
             "Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)","Interview Waiver Visitors (B1/B2)",
             "Interview Waiver Students/Exchange Visitors (F, M, J)","Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)"]
    output = dict(zip(['location_id','location_name',*labels],[cid,name,*output_days]))
    return output

# %%
get_wait_times('P48')
# Out:
# {'location_id': 'P48',
#  'location_name': 'NA',
#  'Interview Required Visitors (B1/B2)': '980 Days',
#  'Interview Required Students/Exchange Visitors (F, M, J)': '37 Days',
#  'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '365 Days',
#  'Interview Waiver Visitors (B1/B2)': '171 Days',
#  'Interview Waiver Students/Exchange Visitors (F, M, J)': '4 Days',
#  'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '298 Days'}

# %%
# for item in codes:
#     try:
#         get_wait_times(item['code'],item['value'])
#     except:
#         print(item)

# %%
# %%time
# results = [get_wait_times(item['code'],item['value']) for item in codes]

# %% [markdown]
# # Get visa times for all places

# %%
with ThreadPoolExecutor(max_workers=os.cpu_count()*2) as pool:
    res = pool.map(get_wait_times,[item['code'] for item in codes],[item['value'] for item in codes])
    res = list(res)

# %%
res
# Out:
# [{'location_id': 'P142',
#   'location_name': 'N Djamena',
#   'Interview Required Visitors (B1/B2)': '65 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '65 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '65 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P142',
#   'location_name': "N'Djamena",
#   'Interview Required Visitors (B1/B2)': '65 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '65 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '65 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'abidjan',
#   'location_name': 'Abidjan',
#   'Interview Required Visitors (B1/B2)': '183 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '77 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P2',
#   'location_name': 'Abu Dhabi',
#   'Interview Required Visitors (B1/B2)': '378 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '295 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '175 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P3',
#   'location_name': 'Abuja',
#   'Interview Required Visitors (B1/B2)': 'Emergency Appointments Only',
#   'Interview Required Students/Exchange Visitors (F, M, J)': 'Emergency Appointments Only',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': 'Emergency Appointments Only',
#   'Interview Waiver Visitors (B1/B2)': 'Emergency Appointments Only',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': 'Emergency Appointments Only',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': 'Emergency Appointments Only'},
#  {'location_id': 'P4',
#   'location_name': 'Accra',
#   'Interview Required Visitors (B1/B2)': '115 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '29 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '30 Days',
#   'Interview Waiver Visitors (B1/B2)': 'Same Day',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': 'Same Day',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': 'Same Day'},
#  {'location_id': 'adana',
#   'location_name': 'Adana',
#   'Interview Required Visitors (B1/B2)': 'Closed',
#   'Interview Required Students/Exchange Visitors (F, M, J)': 'Closed',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': 'Closed',
#   'Interview Waiver Visitors (B1/B2)': 'Closed',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': 'Closed',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': 'Closed'},
#  {'location_id': 'P5',
#   'location_name': 'Addis Ababa',
#   'Interview Required Visitors (B1/B2)': '189 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '33 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '189 Days',
#   'Interview Waiver Visitors (B1/B2)': '7 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '7 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '7 Days'},
#  {'location_id': 'P6',
#   'location_name': 'Algiers',
#   'Interview Required Visitors (B1/B2)': '156 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '65 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '35 Days',
#   'Interview Waiver Visitors (B1/B2)': '30 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '30 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '30 Days'},
#  {'location_id': 'P7',
#   'location_name': 'Almaty',
#   'Interview Required Visitors (B1/B2)': '21 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '4 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '4 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P8',
#   'location_name': 'Amman',
#   'Interview Required Visitors (B1/B2)': '303 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '103 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '7 Days',
#   'Interview Waiver Visitors (B1/B2)': '11 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '26 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '26 Days'},
#  {'location_id': 'P9',
#   'location_name': 'Amsterdam',
#   'Interview Required Visitors (B1/B2)': '143 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '3 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '44 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P10',
#   'location_name': 'Ankara',
#   'Interview Required Visitors (B1/B2)': '137 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '63 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '81 Days',
#   'Interview Waiver Visitors (B1/B2)': '7 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '7 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '7 Days'},
#  {'location_id': 'P11',
#   'location_name': 'Antananarivo',
#   'Interview Required Visitors (B1/B2)': '5 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '5 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '5 Days',
#   'Interview Waiver Visitors (B1/B2)': '5 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '5 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '5 Days'},
#  {'location_id': 'P225',
#   'location_name': 'Apia',
#   'Interview Required Visitors (B1/B2)': '70 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '70 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '70 Days',
#   'Interview Waiver Visitors (B1/B2)': '70 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '70 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '70 Days'},
#  {'location_id': 'P12',
#   'location_name': 'Ashgabat',
#   'Interview Required Visitors (B1/B2)': '3 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '3 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '3 Days',
#   'Interview Waiver Visitors (B1/B2)': '3 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '3 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '3 Days'},
#  {'location_id': 'P13',
#   'location_name': 'Asmara',
#   'Interview Required Visitors (B1/B2)': 'Emergency Appointments Only',
#   'Interview Required Students/Exchange Visitors (F, M, J)': 'Emergency Appointments Only',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': 'Emergency Appointments Only',
#   'Interview Waiver Visitors (B1/B2)': 'Emergency Appointments Only',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': 'Emergency Appointments Only',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': 'Emergency Appointments Only'},
#  {'location_id': 'astana',
#   'location_name': 'Astana',
#   'Interview Required Visitors (B1/B2)': '14 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days',
#   'Interview Waiver Visitors (B1/B2)': 'Same Day',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': 'Same Day',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': 'Same Day'},
#  {'location_id': 'P15',
#   'location_name': 'Asuncion',
#   'Interview Required Visitors (B1/B2)': '211 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '18 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '14 Days',
#   'Interview Waiver Visitors (B1/B2)': '7 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'athens',
#   'location_name': 'Athens',
#   'Interview Required Visitors (B1/B2)': '62 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '3 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '25 Days',
#   'Interview Waiver Visitors (B1/B2)': '3 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '3 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '13 Days'},
#  {'location_id': 'P17',
#   'location_name': 'Auckland',
#   'Interview Required Visitors (B1/B2)': '24 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '23 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '23 Days',
#   'Interview Waiver Visitors (B1/B2)': '24 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '23 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '23 Days'},
#  {'location_id': 'P226',
#   'location_name': 'Baghdad',
#   'Interview Required Visitors (B1/B2)': 'Closed',
#   'Interview Required Students/Exchange Visitors (F, M, J)': 'Closed',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': 'Closed',
#   'Interview Waiver Visitors (B1/B2)': 'Closed',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': 'Closed',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': 'Closed'},
#  {'location_id': 'P19',
#   'location_name': 'Baku',
#   'Interview Required Visitors (B1/B2)': '75 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '2 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '5 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P20',
#   'location_name': 'Bamako',
#   'Interview Required Visitors (B1/B2)': '45 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '7 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '45 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P21',
#   'location_name': 'Bandar Seri Begawan',
#   'Interview Required Visitors (B1/B2)': '7 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '7 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '7 Days',
#   'Interview Waiver Visitors (B1/B2)': '7 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '7 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '7 Days'},
#  {'location_id': 'P22',
#   'location_name': 'Bangkok',
#   'Interview Required Visitors (B1/B2)': '3 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '22 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '22 Days',
#   'Interview Waiver Visitors (B1/B2)': '7 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': 'Same Day',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': 'Same Day'},
#  {'location_id': 'bangui',
#   'location_name': 'Bangui',
#   'Interview Required Visitors (B1/B2)': 'Non-Visa Processing Post',
#   'Interview Required Students/Exchange Visitors (F, M, J)': 'Non-Visa Processing Post',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': 'Non-Visa Processing Post',
#   'Interview Waiver Visitors (B1/B2)': 'Non-Visa Processing Post',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': 'Non-Visa Processing Post',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': 'Non-Visa Processing Post'},
#  {'location_id': 'banjul',
#   'location_name': 'Banjul',
#   'Interview Required Visitors (B1/B2)': '120 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '120 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '120 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'barcelona',
#   'location_name': 'Barcelona',
#   'Interview Required Visitors (B1/B2)': 'Closed',
#   'Interview Required Students/Exchange Visitors (F, M, J)': 'Closed',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': 'Closed',
#   'Interview Waiver Visitors (B1/B2)': 'Closed',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': 'Closed',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': 'Closed'},
#  {'location_id': 'P24',
#   'location_name': 'Beijing',
#   'Interview Required Visitors (B1/B2)': '2 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '2 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '3 Days',
#   'Interview Waiver Visitors (B1/B2)': '',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': ''},
#  {'location_id': 'P25',
#   'location_name': 'Beirut',
#   'Interview Required Visitors (B1/B2)': '156 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '71 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '66 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '999 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '999 Days'},
#  {'location_id': 'P26',
#   'location_name': 'Belfast',
#   'Interview Required Visitors (B1/B2)': '83 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '19 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '19 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P27',
#   'location_name': 'Belgrade',
#   'Interview Required Visitors (B1/B2)': '9 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '2 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '3 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P28',
#   'location_name': 'Belmopan',
#   'Interview Required Visitors (B1/B2)': '61 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '7 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '7 Days',
#   'Interview Waiver Visitors (B1/B2)': '10 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '10 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '10 Days'},
#  {'location_id': 'P29',
#   'location_name': 'Berlin',
#   'Interview Required Visitors (B1/B2)': '80 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '16 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '58 Days',
#   'Interview Waiver Visitors (B1/B2)': 'Same Day',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': 'Same Day',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': 'Same Day'},
#  {'location_id': 'P30',
#   'location_name': 'Bern',
#   'Interview Required Visitors (B1/B2)': '16 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '13 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '16 Days',
#   'Interview Waiver Visitors (B1/B2)': '3 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '3 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '3 Days'},
#  {'location_id': 'P31',
#   'location_name': 'Bishkek',
#   'Interview Required Visitors (B1/B2)': '219 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '18 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '18 Days',
#   'Interview Waiver Visitors (B1/B2)': '219 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '18 Days'},
#  {'location_id': 'P32',
#   'location_name': 'Bogota',
#   'Interview Required Visitors (B1/B2)': '769 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '5 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '6 Days',
#   'Interview Waiver Visitors (B1/B2)': '33 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '33 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '23 Days'},
#  {'location_id': 'P33',
#   'location_name': 'Brasilia',
#   'Interview Required Visitors (B1/B2)': '427 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '2 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '2 Days',
#   'Interview Waiver Visitors (B1/B2)': '20 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P34',
#   'location_name': 'Bratislava',
#   'Interview Required Visitors (B1/B2)': '18 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '9 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '4 Days',
#   'Interview Waiver Visitors (B1/B2)': '5 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '5 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '5 Days'},
#  {'location_id': 'P35',
#   'location_name': 'Brazzaville',
#   'Interview Required Visitors (B1/B2)': '80 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '7 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '80 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P36',
#   'location_name': 'Bridgetown',
#   'Interview Required Visitors (B1/B2)': '21 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '2 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '2 Days',
#   'Interview Waiver Visitors (B1/B2)': '14 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '14 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '14 Days'},
#  {'location_id': 'P37',
#   'location_name': 'Brussels',
#   'Interview Required Visitors (B1/B2)': '39 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '39 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '39 Days',
#   'Interview Waiver Visitors (B1/B2)': '30 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '30 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '30 Days'},
#  {'location_id': 'P38',
#   'location_name': 'Bucharest',
#   'Interview Required Visitors (B1/B2)': '12 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '8 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '12 Days',
#   'Interview Waiver Visitors (B1/B2)': '5 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '5 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '5 Days'},
#  {'location_id': 'P39',
#   'location_name': 'Budapest',
#   'Interview Required Visitors (B1/B2)': '130 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '40 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '40 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P40',
#   'location_name': 'Buenos Aires',
#   'Interview Required Visitors (B1/B2)': '140 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '8 Days',
#   'Interview Waiver Visitors (B1/B2)': '39 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '39 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '39 Days'},
#  {'location_id': 'P41',
#   'location_name': 'Bujumbura',
#   'Interview Required Visitors (B1/B2)': '3 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '3 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '3 Days',
#   'Interview Waiver Visitors (B1/B2)': '',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': ''},
#  {'location_id': 'P42',
#   'location_name': 'Cairo',
#   'Interview Required Visitors (B1/B2)': '119 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '5 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '5 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P43',
#   'location_name': 'Calgary',
#   'Interview Required Visitors (B1/B2)': '153 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '6 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '72 Days',
#   'Interview Waiver Visitors (B1/B2)': '10 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '10 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '10 Days'},
#  {'location_id': 'canberra',
#   'location_name': 'Canberra',
#   'Interview Required Visitors (B1/B2)': 'Non-Visa Processing Post',
#   'Interview Required Students/Exchange Visitors (F, M, J)': 'Non-Visa Processing Post',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': 'Non-Visa Processing Post',
#   'Interview Waiver Visitors (B1/B2)': 'Non-Visa Processing Post',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': 'Non-Visa Processing Post',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': 'Non-Visa Processing Post'},
#  {'location_id': 'P44',
#   'location_name': 'Cape Town',
#   'Interview Required Visitors (B1/B2)': '52 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '22 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '23 Days',
#   'Interview Waiver Visitors (B1/B2)': '5 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '5 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '5 Days'},
#  {'location_id': 'P45',
#   'location_name': 'Caracas',
#   'Interview Required Visitors (B1/B2)': 'Closed',
#   'Interview Required Students/Exchange Visitors (F, M, J)': 'Closed',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': 'Closed',
#   'Interview Waiver Visitors (B1/B2)': 'Closed',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': 'Closed',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': 'Closed'},
#  {'location_id': 'P46',
#   'location_name': 'Casablanca',
#   'Interview Required Visitors (B1/B2)': '120 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '9 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '120 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P47',
#   'location_name': 'Chengdu',
#   'Interview Required Visitors (B1/B2)': 'Closed',
#   'Interview Required Students/Exchange Visitors (F, M, J)': 'Closed',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': 'Closed',
#   'Interview Waiver Visitors (B1/B2)': 'Closed',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': 'Closed',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': 'Closed'},
#  {'location_id': 'P48',
#   'location_name': 'Chennai ( Madras)',
#   'Interview Required Visitors (B1/B2)': '980 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '37 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '365 Days',
#   'Interview Waiver Visitors (B1/B2)': '171 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '4 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '298 Days'},
#  {'location_id': 'P49',
#   'location_name': 'Chiang Mai',
#   'Interview Required Visitors (B1/B2)': '27 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '35 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '35 Days',
#   'Interview Waiver Visitors (B1/B2)': '7 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '7 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '7 Days'},
#  {'location_id': 'P50',
#   'location_name': 'Chisinau',
#   'Interview Required Visitors (B1/B2)': '29 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '7 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '7 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P51',
#   'location_name': 'Ciudad Juarez',
#   'Interview Required Visitors (B1/B2)': '652 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '3 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '2 Days',
#   'Interview Waiver Visitors (B1/B2)': '371 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '371 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '371 Days'},
#  {'location_id': 'P52',
#   'location_name': 'Colombo',
#   'Interview Required Visitors (B1/B2)': '30 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '7 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '7 Days',
#   'Interview Waiver Visitors (B1/B2)': '30 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '60 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '60 Days'},
#  {'location_id': 'P53',
#   'location_name': 'Conakry',
#   'Interview Required Visitors (B1/B2)': '151 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '151 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '14 Days',
#   'Interview Waiver Visitors (B1/B2)': 'Same Day',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': 'Same Day',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': 'Same Day'},
#  {'location_id': 'P54',
#   'location_name': 'Copenhagen',
#   'Interview Required Visitors (B1/B2)': '37 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '4 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '52 Days',
#   'Interview Waiver Visitors (B1/B2)': '3 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '3 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '3 Days'},
#  {'location_id': 'P55',
#   'location_name': 'Cotonou',
#   'Interview Required Visitors (B1/B2)': '168 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '168 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '168 Days',
#   'Interview Waiver Visitors (B1/B2)': '168 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '168 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '168 Days'},
#  {'location_id': 'P223',
#   'location_name': 'Curacao',
#   'Interview Required Visitors (B1/B2)': '50 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '21 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '21 Days',
#   'Interview Waiver Visitors (B1/B2)': '14 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '14 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '14 Days'},
#  {'location_id': 'P56',
#   'location_name': 'Dakar',
#   'Interview Required Visitors (B1/B2)': '189 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '15 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '10 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P57',
#   'location_name': 'Damascus',
#   'Interview Required Visitors (B1/B2)': 'Closed',
#   'Interview Required Students/Exchange Visitors (F, M, J)': 'Closed',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': 'Closed',
#   'Interview Waiver Visitors (B1/B2)': 'Closed',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': 'Closed',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': 'Closed'},
#  {'location_id': 'P58',
#   'location_name': 'Dar Es Salaam',
#   'Interview Required Visitors (B1/B2)': '92 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '67 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '67 Days',
#   'Interview Waiver Visitors (B1/B2)': '16 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '67 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '67 Days'},
#  {'location_id': 'P59',
#   'location_name': 'Dhahran',
#   'Interview Required Visitors (B1/B2)': '53 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '11 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '16 Days',
#   'Interview Waiver Visitors (B1/B2)': '7 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '7 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '7 Days'},
#  {'location_id': 'P60',
#   'location_name': 'Dhaka',
#   'Interview Required Visitors (B1/B2)': '274 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '162 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '6 Days',
#   'Interview Waiver Visitors (B1/B2)': '14 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '15 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '14 Days'},
#  {'location_id': 'P227',
#   'location_name': 'Dili',
#   'Interview Required Visitors (B1/B2)': '1 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days',
#   'Interview Waiver Visitors (B1/B2)': '',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': ''},
#  {'location_id': 'P61',
#   'location_name': 'Djibouti',
#   'Interview Required Visitors (B1/B2)': '4 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '4 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '4 Days',
#   'Interview Waiver Visitors (B1/B2)': '4 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '4 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '4 Days'},
#  {'location_id': 'P62',
#   'location_name': 'Doha',
#   'Interview Required Visitors (B1/B2)': '52 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '36 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '42 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P63',
#   'location_name': 'Dubai',
#   'Interview Required Visitors (B1/B2)': '449 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '128 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '133 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P64',
#   'location_name': 'Dublin',
#   'Interview Required Visitors (B1/B2)': '22 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '14 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '10 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P65',
#   'location_name': 'Durban',
#   'Interview Required Visitors (B1/B2)': '85 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '2 Days',
#   'Interview Waiver Visitors (B1/B2)': '3 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '3 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '3 Days'},
#  {'location_id': 'P66',
#   'location_name': 'Dushanbe',
#   'Interview Required Visitors (B1/B2)': '53 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '53 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '53 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'erbil',
#   'location_name': 'Erbil',
#   'Interview Required Visitors (B1/B2)': '250 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '11 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '11 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P67',
#   'location_name': 'Florence',
#   'Interview Required Visitors (B1/B2)': '9 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days',
#   'Interview Waiver Visitors (B1/B2)': 'Same Day',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': 'Same Day',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': 'Same Day'},
#  {'location_id': 'P68',
#   'location_name': 'Frankfurt',
#   'Interview Required Visitors (B1/B2)': '67 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '14 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '14 Days',
#   'Interview Waiver Visitors (B1/B2)': 'Same Day',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': 'Same Day',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': 'Same Day'},
#  {'location_id': 'P69',
#   'location_name': 'Freetown',
#   'Interview Required Visitors (B1/B2)': '126 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '126 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '126 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'fukuoka',
#   'location_name': 'Fukuoka',
#   'Interview Required Visitors (B1/B2)': '30 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '21 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '21 Days',
#   'Interview Waiver Visitors (B1/B2)': '',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': ''},
#  {'location_id': 'P70',
#   'location_name': 'Gaborone',
#   'Interview Required Visitors (B1/B2)': '14 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '14 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '14 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P71',
#   'location_name': 'Georgetown',
#   'Interview Required Visitors (B1/B2)': '92 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P72',
#   'location_name': 'Guadalajara',
#   'Interview Required Visitors (B1/B2)': '814 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '7 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '8 Days',
#   'Interview Waiver Visitors (B1/B2)': '262 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '262 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '262 Days'},
#  {'location_id': 'P73',
#   'location_name': 'Guangzhou',
#   'Interview Required Visitors (B1/B2)': '31 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '2 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '31 Days',
#   'Interview Waiver Visitors (B1/B2)': 'Same Day',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': 'Same Day',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': 'Same Day'},
#  {'location_id': 'P74',
#   'location_name': 'Guatemala City',
#   'Interview Required Visitors (B1/B2)': '183 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '3 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '3 Days',
#   'Interview Waiver Visitors (B1/B2)': '4 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '3 Days'},
#  {'location_id': 'P75',
#   'location_name': 'Guayaquil',
#   'Interview Required Visitors (B1/B2)': '189 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '68 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '42 Days',
#   'Interview Waiver Visitors (B1/B2)': '32 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '32 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '32 Days'},
#  {'location_id': 'P76',
#   'location_name': 'Halifax',
#   'Interview Required Visitors (B1/B2)': '201 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '8 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '80 Days',
#   'Interview Waiver Visitors (B1/B2)': '10 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '10 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '10 Days'},
#  {'location_id': 'P77',
#   'location_name': 'Hamilton',
#   'Interview Required Visitors (B1/B2)': '120 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '15 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '60 Days',
#   'Interview Waiver Visitors (B1/B2)': '',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': ''},
#  {'location_id': 'P78',
#   'location_name': 'Hanoi',
#   'Interview Required Visitors (B1/B2)': '14 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '3 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '23 Days',
#   'Interview Waiver Visitors (B1/B2)': '7 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '7 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '7 Days'},
#  {'location_id': 'P79',
#   'location_name': 'Harare',
#   'Interview Required Visitors (B1/B2)': '3 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '3 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '3 Days',
#   'Interview Waiver Visitors (B1/B2)': '3 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '3 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '3 Days'},
#  {'location_id': 'P80',
#   'location_name': 'Havana',
#   'Interview Required Visitors (B1/B2)': 'Emergency Appointments Only',
#   'Interview Required Students/Exchange Visitors (F, M, J)': 'Emergency Appointments Only',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': 'Emergency Appointments Only',
#   'Interview Waiver Visitors (B1/B2)': 'Emergency Appointments Only',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': 'Emergency Appointments Only',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': 'Emergency Appointments Only'},
#  {'location_id': 'P81',
#   'location_name': 'Helsinki',
#   'Interview Required Visitors (B1/B2)': '65 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '45 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '64 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P82',
#   'location_name': 'Hermosillo',
#   'Interview Required Visitors (B1/B2)': '577 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '16 Days',
#   'Interview Waiver Visitors (B1/B2)': '169 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '2 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '2 Days'},
#  {'location_id': 'P83',
#   'location_name': 'Ho Chi Minh City',
#   'Interview Required Visitors (B1/B2)': '14 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '14 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '7 Days',
#   'Interview Waiver Visitors (B1/B2)': '5 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '5 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '5 Days'},
#  {'location_id': 'P84',
#   'location_name': 'Hong Kong',
#   'Interview Required Visitors (B1/B2)': '2 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '2 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '4 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P85',
#   'location_name': 'Hyderabad',
#   'Interview Required Visitors (B1/B2)': '999 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '37 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '367 Days',
#   'Interview Waiver Visitors (B1/B2)': '232 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '71 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '309 Days'},
#  {'location_id': 'P86',
#   'location_name': 'Islamabad',
#   'Interview Required Visitors (B1/B2)': '323 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '2 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '2 Days',
#   'Interview Waiver Visitors (B1/B2)': '5 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '5 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '5 Days'},
#  {'location_id': 'P87',
#   'location_name': 'Istanbul',
#   'Interview Required Visitors (B1/B2)': '305 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '226 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '64 Days',
#   'Interview Waiver Visitors (B1/B2)': 'Same Day',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': 'Same Day',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': 'Same Day'},
#  {'location_id': 'P88',
#   'location_name': 'Jakarta',
#   'Interview Required Visitors (B1/B2)': '16 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '7 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '2 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P89',
#   'location_name': 'Jeddah',
#   'Interview Required Visitors (B1/B2)': '57 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '15 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days',
#   'Interview Waiver Visitors (B1/B2)': '2 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '2 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '2 Days'},
#  {'location_id': 'P90',
#   'location_name': 'Jerusalem',
#   'Interview Required Visitors (B1/B2)': '219 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '53 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days',
#   'Interview Waiver Visitors (B1/B2)': 'Same Day',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '46 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P91',
#   'location_name': 'Johannesburg',
#   'Interview Required Visitors (B1/B2)': '7 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '7 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '7 Days',
#   'Interview Waiver Visitors (B1/B2)': '8 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P228',
#   'location_name': 'Juba',
#   'Interview Required Visitors (B1/B2)': 'Closed',
# ...
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P191',
#   'location_name': 'Sofia',
#   'Interview Required Visitors (B1/B2)': '37 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '17 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '37 Days',
#   'Interview Waiver Visitors (B1/B2)': '14 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '14 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '14 Days'},
#  {'location_id': 'st_georges',
#   'location_name': 'St Georges',
#   'Interview Required Visitors (B1/B2)': 'Closed',
#   'Interview Required Students/Exchange Visitors (F, M, J)': 'Closed',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': 'Closed',
#   'Interview Waiver Visitors (B1/B2)': 'Closed',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': 'Closed',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': 'Closed'},
#  {'location_id': 'P192',
#   'location_name': 'St Petersburg',
#   'Interview Required Visitors (B1/B2)': 'Closed',
#   'Interview Required Students/Exchange Visitors (F, M, J)': 'Closed',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': 'Closed',
#   'Interview Waiver Visitors (B1/B2)': 'Closed',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': 'Closed',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': 'Closed'},
#  {'location_id': 'P193',
#   'location_name': 'Stockholm',
#   'Interview Required Visitors (B1/B2)': '44 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '7 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days',
#   'Interview Waiver Visitors (B1/B2)': '14 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '14 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '14 Days'},
#  {'location_id': 'P194',
#   'location_name': 'Surabaya',
#   'Interview Required Visitors (B1/B2)': '41 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '2 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '2 Days',
#   'Interview Waiver Visitors (B1/B2)': '2 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P195',
#   'location_name': 'Suva',
#   'Interview Required Visitors (B1/B2)': '11 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '3 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '2 Days',
#   'Interview Waiver Visitors (B1/B2)': '3 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '3 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '3 Days'},
#  {'location_id': 'P196',
#   'location_name': 'Sydney',
#   'Interview Required Visitors (B1/B2)': '69 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '23 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '64 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P197',
#   'location_name': 'Taipei',
#   'Interview Required Visitors (B1/B2)': '27 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '7 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '7 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P198',
#   'location_name': 'Tallinn',
#   'Interview Required Visitors (B1/B2)': '1 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P199',
#   'location_name': 'Tashkent',
#   'Interview Required Visitors (B1/B2)': '120 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '30 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '30 Days',
#   'Interview Waiver Visitors (B1/B2)': '30 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '30 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '30 Days'},
#  {'location_id': 'P200',
#   'location_name': 'Tbilisi',
#   'Interview Required Visitors (B1/B2)': '247 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '23 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '66 Days',
#   'Interview Waiver Visitors (B1/B2)': 'Same Day',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': 'Same Day',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': 'Same Day'},
#  {'location_id': 'P201',
#   'location_name': 'Tegucigalpa',
#   'Interview Required Visitors (B1/B2)': '2 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '2 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '2 Days',
#   'Interview Waiver Visitors (B1/B2)': '66 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '2 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '2 Days'},
#  {'location_id': 'P202',
#   'location_name': 'Tel Aviv',
#   'Interview Required Visitors (B1/B2)': '199 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '2 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '5 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'tijuana',
#   'location_name': 'Tijuana',
#   'Interview Required Visitors (B1/B2)': '626 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days',
#   'Interview Waiver Visitors (B1/B2)': '423 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P203',
#   'location_name': 'Tijuana Tpf',
#   'Interview Required Visitors (B1/B2)': '626 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days',
#   'Interview Waiver Visitors (B1/B2)': '423 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P204',
#   'location_name': 'Tirana',
#   'Interview Required Visitors (B1/B2)': '138 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '14 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '14 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P205',
#   'location_name': 'Tokyo',
#   'Interview Required Visitors (B1/B2)': '43 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '2 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '2 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P206',
#   'location_name': 'Toronto',
#   'Interview Required Visitors (B1/B2)': '464 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '51 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '71 Days',
#   'Interview Waiver Visitors (B1/B2)': '10 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '10 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '10 Days'},
#  {'location_id': 'P207',
#   'location_name': 'Tripoli',
#   'Interview Required Visitors (B1/B2)': 'Closed',
#   'Interview Required Students/Exchange Visitors (F, M, J)': 'Closed',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': 'Closed',
#   'Interview Waiver Visitors (B1/B2)': 'Closed',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': 'Closed',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': 'Closed'},
#  {'location_id': 'P208',
#   'location_name': 'Tunis',
#   'Interview Required Visitors (B1/B2)': '150 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '21 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '14 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P209',
#   'location_name': 'Ulaanbaatar',
#   'Interview Required Visitors (B1/B2)': '130 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '35 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '15 Days',
#   'Interview Waiver Visitors (B1/B2)': '44 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '44 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '44 Days'},
#  {'location_id': 'usun-new_york',
#   'location_name': 'Usun-New York',
#   'Interview Required Visitors (B1/B2)': '7 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '7 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '7 Days',
#   'Interview Waiver Visitors (B1/B2)': '',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': ''},
#  {'location_id': 'P210',
#   'location_name': 'Valletta',
#   'Interview Required Visitors (B1/B2)': '30 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '15 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '30 Days',
#   'Interview Waiver Visitors (B1/B2)': '',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': ''},
#  {'location_id': 'P211',
#   'location_name': 'Vancouver',
#   'Interview Required Visitors (B1/B2)': '329 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '6 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '146 Days',
#   'Interview Waiver Visitors (B1/B2)': '10 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '10 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '10 Days'},
#  {'location_id': 'P212',
#   'location_name': 'Vienna',
#   'Interview Required Visitors (B1/B2)': '43 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '37 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '37 Days',
#   'Interview Waiver Visitors (B1/B2)': '5 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '5 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '5 Days'},
#  {'location_id': 'P213',
#   'location_name': 'Vientiane',
#   'Interview Required Visitors (B1/B2)': '79 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '30 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '30 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P214',
#   'location_name': 'Vilnius',
#   'Interview Required Visitors (B1/B2)': '2 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '2 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '2 Days',
#   'Interview Waiver Visitors (B1/B2)': 'Same Day',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': 'Same Day',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P215',
#   'location_name': 'Vladivostok',
#   'Interview Required Visitors (B1/B2)': 'Closed',
#   'Interview Required Students/Exchange Visitors (F, M, J)': 'Closed',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': 'Closed',
#   'Interview Waiver Visitors (B1/B2)': 'Closed',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': 'Closed',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': 'Closed'},
#  {'location_id': 'P216',
#   'location_name': 'Warsaw',
#   'Interview Required Visitors (B1/B2)': '3 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days',
#   'Interview Waiver Visitors (B1/B2)': '2 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '2 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '2 Days'},
#  {'location_id': 'P217',
#   'location_name': 'Windhoek',
#   'Interview Required Visitors (B1/B2)': '58 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '30 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '30 Days',
#   'Interview Waiver Visitors (B1/B2)': '30 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '30 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '30 Days'},
#  {'location_id': 'P218',
#   'location_name': 'Yaounde',
#   'Interview Required Visitors (B1/B2)': '9 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '9 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '13 Days',
#   'Interview Waiver Visitors (B1/B2)': 'Same Day',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': 'Same Day',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': 'Same Day'},
#  {'location_id': 'yekaterinburg',
#   'location_name': 'Yekaterinburg',
#   'Interview Required Visitors (B1/B2)': 'Closed',
#   'Interview Required Students/Exchange Visitors (F, M, J)': 'Closed',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': 'Closed',
#   'Interview Waiver Visitors (B1/B2)': 'Closed',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': 'Closed',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': 'Closed'},
#  {'location_id': 'P220',
#   'location_name': 'Yerevan',
#   'Interview Required Visitors (B1/B2)': '260 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '120 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '79 Days',
#   'Interview Waiver Visitors (B1/B2)': '1 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '1 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '1 Days'},
#  {'location_id': 'P221',
#   'location_name': 'Zagreb',
#   'Interview Required Visitors (B1/B2)': '94 Days',
#   'Interview Required Students/Exchange Visitors (F, M, J)': '7 Days',
#   'Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)': '30 Days',
#   'Interview Waiver Visitors (B1/B2)': '10 Days',
#   'Interview Waiver Students/Exchange Visitors (F, M, J)': '10 Days',
#   'Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)': '10 Days'}]

# %% [markdown]
# # convert responses to json

# %%
df = pd.DataFrame(res)

# %%
df
# Out:
#        location_id  location_name Interview Required Visitors (B1/B2)  \
# 0             P142      N Djamena                             65 Days
# 1             P142      N'Djamena                             65 Days
# 2          abidjan        Abidjan                            183 Days
# 3               P2      Abu Dhabi                            378 Days
# 4               P3          Abuja         Emergency Appointments Only
# ..             ...            ...                                 ...
# 239           P217       Windhoek                             58 Days
# 240           P218        Yaounde                              9 Days
# 241  yekaterinburg  Yekaterinburg                              Closed
# 242           P220        Yerevan                            260 Days
# 243           P221         Zagreb                             94 Days
#
#     Interview Required Students/Exchange Visitors (F, M, J)  \
# 0                                              65 Days
# 1                                              65 Days
# 2                                              77 Days
# 3                                             295 Days
# 4                          Emergency Appointments Only
# ..                                                 ...
# 239                                            30 Days
# 240                                             9 Days
# 241                                             Closed
# 242                                           120 Days
# 243                                             7 Days
#
#     Interview Required Petition-Based Temporary Workers (H, L, O, P, Q)  \
# 0                                              65 Days
# 1                                              65 Days
# 2                                               1 Days
# 3                                             175 Days
# 4                          Emergency Appointments Only
# ..                                                 ...
# 239                                            30 Days
# 240                                            13 Days
# 241                                             Closed
# 242                                            79 Days
# 243                                            30 Days
#
#     Interview Waiver Visitors (B1/B2)  \
# 0                              1 Days
# 1                              1 Days
# 2                              1 Days
# 3                              1 Days
# 4         Emergency Appointments Only
# ..                                ...
# 239                           30 Days
# 240                          Same Day
# 241                            Closed
# 242                            1 Days
# 243                           10 Days
#
#     Interview Waiver Students/Exchange Visitors (F, M, J)  \
# 0                                               1 Days
# 1                                               1 Days
# 2                                               1 Days
# 3                                               1 Days
# 4                          Emergency Appointments Only
# ..                                                 ...
# 239                                            30 Days
# 240                                           Same Day
# 241                                             Closed
# 242                                             1 Days
# 243                                            10 Days
#
#     Interview Waiver Petition-Based Temporary Workers (H, L, O, P, Q)
# 0                                               1 Days
# 1                                               1 Days
# 2                                               1 Days
# 3                                               1 Days
# 4                          Emergency Appointments Only
# ..                                                 ...
# 239                                            30 Days
# 240                                           Same Day
# 241                                             Closed
# 242                                             1 Days
# 243                                            10 Days
#
# [244 rows x 8 columns]

# %% [markdown]
# # Save data

# %% [markdown]
# ## Getting current time

# %%
timezone = 'Asia/Kolkata'

# %%
current_time = datetime.now(pytz.timezone(timezone))
current_time
# Out:
# datetime.datetime(2022, 12, 2, 23, 46, 17, 831979, tzinfo=<DstTzInfo 'Asia/Kolkata' IST+5:30:00 STD>)

# %%
timestamp = current_time.strftime('%y-%m-%d_%H:%M:%S')
timestamp
# Out:
# '22-12-02_23:46:17'

# %% [markdown]
# ## Save the file to csv and xlsx

# %%
df.to_excel(f'us_visa_app_times_{timestamp}.xlsx',index=False)
df.to_csv(f'us_visa_app_times_{timestamp}.csv',index=False)
